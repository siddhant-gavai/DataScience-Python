# %%
a = input("enter the value of a") # be default it takes user input as string
# Out:
# enter the value of a 32

# %%
print(a)
# Out:
# 32

# %%
b = input("enter the value of b")
# Out:
# enter the value of b 66

# %%
b
# Out:
# '66'

# %%
a + b
# Out:
# '3266'

# %%
int(a) + int(b) # after typecasting you get the right answer
# Out:
# 98

# %%
c = input()
# Out:
#  90

# %%
c
# Out:
# '90'
