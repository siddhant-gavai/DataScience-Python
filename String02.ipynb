# %%
name = "siddhant"

# %%
name
# Out:
# 'siddhant'

# %%
name.upper()
# Out:
# 'SIDDHANT'

# %%
name.endswith("nt")
# Out:
# True

# %%
name
# Out:
# 'siddhant'

# %%
s = "siddhant"

# %%
print(s.strip()) # for remove spaces
# Out:
# siddhant

# %%
s = "hello world"
print(s.replace("world", "bro"))  # hello bro
# Out:
# hello bro

# %%
s = "apple,banana,mango"
print(s.split(","))  # ['apple', 'banana', 'mango']
# Out:
# ['apple', 'banana', 'mango']

# %%
s = "siddhant"

# %%
s.find("d")
# Out:
# 2

# %%
s.count("d")
# Out:
# 2

# %%
len(s)
# Out:
# 8

# %%
s[0:5]
# Out:
# 'siddh'

# %%
s[6]
# Out:
# 'n'
