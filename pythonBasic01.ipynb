# %% [markdown]
# # Topic: Python Basics
# ### Author: Siddhant Gavai
# ### Date: April 2026
# ---

# %%
a=3

# %%
a
# Out:
# 3

# %%
str1 = "siddhant"

# %%
print(str1)
# Out:
# siddhant

# %%
print(str1)
# Out:
# siddhant

# %%
str2 = "shreya" # this is will save shreya on str2

# %%
print(str2)
# Out:
# shreya

# %%
# this is a comment  for learning python

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(str2))
# Out:
# <class 'str'>

# %%
# typecasting

# %%
type(str2)
# Out:
# str

# %%
a = "2323"

# %%
b = "3232"

# %%
print(a+b) # only print addup string
# Out:
# 23233232

# %%
print(int(a)+int(b)) # this will print sum of a + b
# Out:
# 5555
