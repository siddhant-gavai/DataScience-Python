# %% [markdown]
# # Topic: If Else Conditions
# ### Author: Siddhant Gavai
# ### Date: April 2026
# ---

# %% [markdown]
# # 06 - If Else Conditions
#
# This notebook covers the basic usage of `if`, `elif`, and `else` statements in Python.

# %%
age = 18
if age >= 18:
    print("You are an adult.")
else:
    print("You are a minor.")

# %%
score = 85
if score >= 90:
    print("Grade: A")
elif score >= 80:
    print("Grade: B")
else:
    print("Grade: C")
