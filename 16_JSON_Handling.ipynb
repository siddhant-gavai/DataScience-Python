# %% [markdown]
# # Topic: JSON Handling in Python
# ### Author: Siddhant Gavai
# ### Date: April 2026
# ---

# %% [markdown]
# # 16 - JSON Handling in Python
#
# JSON (JavaScript Object Notation) is a lightweight data-interchange format. Python has a built-in package called `json`, which can be used to work with JSON data.

# %% [markdown]
# ### Importing the json module

# %%
import json

# %% [markdown]
# ### Reading JSON from a File
#
# We use `json.load()` to read data from a file object.

# %%
with open('data.json', 'r') as f:
    data = json.load(f)

print("Data loaded from data.json:")
print(data)
print(f"\nName: {data['name']}")
print(f"Skills: {', '.join(data['skills'])}")
# Out:
# Data loaded from data.json:
# {'name': 'Siddhant Gavai', 'role': 'Data Scientist', 'skills': ['Python', 'Machine Learning', 'Data Analysis', 'SQL'], 'projects': [{'title': 'MediConnect', 'description': 'Healthcare appointment booking system', 'tech_stack': ['React', 'Node.js', 'PostgreSQL', 'Prisma']}, {'title': 'DataScience-Python', 'description': 'Comprehensive guide to Python for Data Science', 'tech_stack': ['Python', 'Jupyter Notebooks']}], 'contact': {'email': 'siddhant@example.com', 'github': 'siddhant-gavai'}}
#
# Name: Siddhant Gavai
# Skills: Python, Machine Learning, Data Analysis, SQL

# %% [markdown]
# ### Writing JSON to a File
#
# We use `json.dump()` to write data to a file object.

# %%
new_data = {
    "name": "Siddhant Gavai",
    "role": "Data Scientist",
    "updated": True
}

with open('updated_data.json', 'w') as f:
    json.dump(new_data, f, indent=4)

print("New data written to updated_data.json")
# Out:
# New data written to updated_data.json

# %% [markdown]
# ### Parsing JSON Strings
#
# - `json.loads()`: Parses a JSON string.
# - `json.dumps()`: Converts a Python object into a JSON string.

# %%
# JSON string to Python dictionary
json_string = '{"city": "New York", "population": 8419000}'
python_dict = json.loads(json_string)
print(f"City: {python_dict['city']}")

# Python dictionary to JSON string
back_to_json = json.dumps(python_dict, indent=2)
print("\nJSON String:")
print(back_to_json)
# Out:
# City: New York
#
# JSON String:
# {
#   "city": "New York",
#   "population": 8419000
# }
